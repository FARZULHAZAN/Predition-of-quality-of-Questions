# %%
import xml.etree.ElementTree as et
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import numpy as np
from sklearn.model_selection import StratifiedKFold
import seaborn as c
import matplotlib.pyplot as pl
from sklearn.metrics import accuracy_score
from sklearn.model_selection import StratifiedKFold
from sklearn.model_selection import cross_val_score

# %%
df=et.parse(r"C:\Users\91701\Desktop\project\physics.stackexchange.com\Posts.xml")

# %%
root=df.getroot()

# %%
root
# Out:
# <Element 'posts' at 0x00000261218B8C20>

# %%
root[0]
# Out:
# <Element 'row' at 0x00000261218B8E50>

# %%
s=[]
for i in root:
    s.append(i.attrib)

# %%
len(s)
# Out:
# 345199

# %%
file=pd.DataFrame(s)

# %%
file.columns
# Out:
# Index(['Id', 'PostTypeId', 'AcceptedAnswerId', 'CreationDate', 'Score',
#        'ViewCount', 'Body', 'OwnerUserId', 'LastEditorUserId', 'LastEditDate',
#        'LastActivityDate', 'Title', 'Tags', 'AnswerCount', 'CommentCount',
#        'FavoriteCount', 'ParentId', 'OwnerDisplayName', 'ClosedDate',
#        'LastEditorDisplayName', 'CommunityOwnedDate'],
#       dtype='object')

# %%
file=file.drop(['LastEditorDisplayName',
            'ClosedDate',
            'OwnerDisplayName','LastEditorUserId',
           'AcceptedAnswerId','CommunityOwnedDate','ParentId','CommunityOwnedDate','OwnerUserId',
                'PostTypeId','LastActivityDate','LastEditDate','CreationDate'],axis=1)

# %%
file=file.dropna()

# %%
file.dtypes
# Out:
# Id               object
# Score            object
# ViewCount        object
# Body             object
# Title            object
# Tags             object
# AnswerCount      object
# CommentCount     object
# FavoriteCount    object
# dtype: object

# %%
file['Id']=file['Id'].astype(int)

# %%
file['Score']=file['Score'].astype(int)

# %%
file['ViewCount']=file['ViewCount'].astype(int)

# %%
file['AnswerCount']=file['AnswerCount'].astype(int)

# %%
file['CommentCount']=file['CommentCount'].astype(int)

# %%
file['FavoriteCount']=file['FavoriteCount'].astype(int)

# %%
file.dtypes
# Out:
# Id                int32
# Score             int32
# ViewCount         int32
# Body             object
# Title            object
# Tags             object
# AnswerCount       int32
# CommentCount      int32
# FavoriteCount     int32
# dtype: object

# %%
quality=file.loc[:,['AnswerCount','Score']]

# %%
quality['Quality'] = np.where(quality['Score'] > 5,
    np.where(quality['AnswerCount'] > 0, 'Good', 'Low'),
    np.where(quality['Score'] < 0, 'Very Low', 'Low'))

# %%
quality
# Out:
#         AnswerCount  Score Quality
# 0                 5     76    Good
# 1                 4     29    Good
# 2                 3     35    Good
# 5                 6     10    Good
# 7                 6     48    Good
# ...             ...    ...     ...
# 345086            0      1     Low
# 345090            0      0     Low
# 345097            2      0     Low
# 345117            4     14    Good
# 345177            0      0     Low
#
# [58276 rows x 3 columns]

# %%
q=quality['Quality']

# %%
file
# Out:
#             Id  Score  ViewCount  \
# 0            1     76      13803
# 1            2     29       2641
# 2            3     35       2412
# 5            7     10       2033
# 7            9     48       9277
# ...        ...    ...        ...
# 345086  483671      1         24
# 345090  483675      0         22
# 345097  483682      0         60
# 345117  483702     14        318
# 345177  483765      0         26
#
#                                                      Body  \
# 0       <p>I often hear about subatomic particles havi...
# 1       <p>How would you explain string theory to non ...
# 2       <p>This is a question that has been posted at ...
# 5       <p>What are the main problems that we need to ...
# 7       <p>Hamilton's principle states that a dynamic ...
# ...                                                   ...
# 345086  <p>If lagrangian is dependent only on <span cl...
# 345090  <p>Let there be a ring of mass m and radius r....
# 345097  <p>Just watched a video explaining how oil fil...
# 345117  <p>I have been taught that the boundary condit...
# 345177  <p>I am <strong>not</strong> happy about the d...
#
#                                                     Title  \
# 0       What is spin as it relates to subatomic partic...
# 1       What is your simplest explanation of the strin...
# 2        Lie theory, Representations and particle physics
# 5                      Will Determinism be ever possible?
# 7                                    Hamilton's Principle
# ...                                                   ...
# 345086                      Lagrangian for inertial frame
# 345090                       A basic question on rotation
# 345097  EM waves cancelling each other - do they inter...
# 345117  Why does the Schrödinger equation work so well...
# 345177  A specific derivation of Yang-Mills equations ...
#
#                                                      Tags  AnswerCount  \
# 0       <quantum-mechanics><particle-physics><angular-...            5
# 1                              <string-theory><education>            4
# 2       <particle-physics><group-theory><representatio...            3
# 5       <quantum-mechanics><quantum-interpretations><h...            6
# 7       <lagrangian-formalism><variational-principle><...            6
# ...                                                   ...          ...
# 345086  <special-relativity><classical-mechanics><refe...            0
# 345090  <homework-and-exercises><rotational-dynamics><...            0
# 345097  <quantum-mechanics><electromagnetic-radiation>...            2
# 345117  <quantum-mechanics><schroedinger-equation><coo...            4
# 345177  <classical-mechanics><differential-geometry><t...            0
#
#         CommentCount  FavoriteCount
# 0                  5             27
# 1                  4              8
# 2                  5             13
# 5                  5              5
# 7                  2             32
# ...              ...            ...
# 345086             2              1
# 345090             0              1
# 345097             2              1
# 345117             6              4
# 345177             1              1
#
# [58276 rows x 9 columns]

# %%
file=file.drop(['AnswerCount','Score'],axis=1)

# %%
file=pd.concat([file,q],axis=1)

# %%
file
# Out:
#             Id  ViewCount                                               Body  \
# 0            1      13803  <p>I often hear about subatomic particles havi...
# 1            2       2641  <p>How would you explain string theory to non ...
# 2            3       2412  <p>This is a question that has been posted at ...
# 5            7       2033  <p>What are the main problems that we need to ...
# 7            9       9277  <p>Hamilton's principle states that a dynamic ...
# ...        ...        ...                                                ...
# 345086  483671         24  <p>If lagrangian is dependent only on <span cl...
# 345090  483675         22  <p>Let there be a ring of mass m and radius r....
# 345097  483682         60  <p>Just watched a video explaining how oil fil...
# 345117  483702        318  <p>I have been taught that the boundary condit...
# 345177  483765         26  <p>I am <strong>not</strong> happy about the d...
#
#                                                     Title  \
# 0       What is spin as it relates to subatomic partic...
# 1       What is your simplest explanation of the strin...
# 2        Lie theory, Representations and particle physics
# 5                      Will Determinism be ever possible?
# 7                                    Hamilton's Principle
# ...                                                   ...
# 345086                      Lagrangian for inertial frame
# 345090                       A basic question on rotation
# 345097  EM waves cancelling each other - do they inter...
# 345117  Why does the Schrödinger equation work so well...
# 345177  A specific derivation of Yang-Mills equations ...
#
#                                                      Tags  CommentCount  \
# 0       <quantum-mechanics><particle-physics><angular-...             5
# 1                              <string-theory><education>             4
# 2       <particle-physics><group-theory><representatio...             5
# 5       <quantum-mechanics><quantum-interpretations><h...             5
# 7       <lagrangian-formalism><variational-principle><...             2
# ...                                                   ...           ...
# 345086  <special-relativity><classical-mechanics><refe...             2
# 345090  <homework-and-exercises><rotational-dynamics><...             0
# 345097  <quantum-mechanics><electromagnetic-radiation>...             2
# 345117  <quantum-mechanics><schroedinger-equation><coo...             6
# 345177  <classical-mechanics><differential-geometry><t...             1
#
#         FavoriteCount Quality
# 0                  27    Good
# 1                   8    Good
# 2                  13    Good
# 5                   5    Good
# 7                  32    Good
# ...               ...     ...
# 345086              1     Low
# 345090              1     Low
# 345097              1     Low
# 345117              4    Good
# 345177              1     Low
#
# [58276 rows x 8 columns]

# %%
file.iloc[25,3]
# Out:
# 'Mnemonics to remember various properties of materials'

# %%
from bs4 import BeautifulSoup
html_generator = (html_string for html_string in list(file['Body']))
# Split the HTML strings into batches of size 1000
batch_size = 1000
html_batches = [list(file['Body'])[i:i+batch_size] for i in range(0, len(list(file['Body'])), batch_size)]
# Process each batch of HTML strings
text_list = []
for html_batch in html_batches:
    batch_text_list = []
    for html_string in html_batch:
        soup = BeautifulSoup(html_string, "html.parser")
        text = soup.get_text()
        batch_text_list.append(text)
    text_list.extend(batch_text_list)

# %%
file['Body']=text_list

# %%
file
# Out:
#             Id  ViewCount                                               Body  \
# 0            1      13803  I often hear about subatomic particles having ...
# 1            2       2641  How would you explain string theory to non phy...
# 2            3       2412  This is a question that has been posted at man...
# 5            7       2033  What are the main problems that we need to sol...
# 7            9       9277  Hamilton's principle states that a dynamic sys...
# ...        ...        ...                                                ...
# 345086  483671         24  If lagrangian is dependent only on $v^2$, then...
# 345090  483675         22  Let there be a ring of mass m and radius r. Le...
# 345097  483682         60  Just watched a video explaining how oil film c...
# 345117  483702        318  I have been taught that the boundary condition...
# 345177  483765         26  I am not happy about the derivation of Yang-Mi...
#
#                                                     Title  \
# 0       What is spin as it relates to subatomic partic...
# 1       What is your simplest explanation of the strin...
# 2        Lie theory, Representations and particle physics
# 5                      Will Determinism be ever possible?
# 7                                    Hamilton's Principle
# ...                                                   ...
# 345086                      Lagrangian for inertial frame
# 345090                       A basic question on rotation
# 345097  EM waves cancelling each other - do they inter...
# 345117  Why does the Schrödinger equation work so well...
# 345177  A specific derivation of Yang-Mills equations ...
#
#                                                      Tags  CommentCount  \
# 0       <quantum-mechanics><particle-physics><angular-...             5
# 1                              <string-theory><education>             4
# 2       <particle-physics><group-theory><representatio...             5
# 5       <quantum-mechanics><quantum-interpretations><h...             5
# 7       <lagrangian-formalism><variational-principle><...             2
# ...                                                   ...           ...
# 345086  <special-relativity><classical-mechanics><refe...             2
# 345090  <homework-and-exercises><rotational-dynamics><...             0
# 345097  <quantum-mechanics><electromagnetic-radiation>...             2
# 345117  <quantum-mechanics><schroedinger-equation><coo...             6
# 345177  <classical-mechanics><differential-geometry><t...             1
#
#         FavoriteCount Quality
# 0                  27    Good
# 1                   8    Good
# 2                  13    Good
# 5                   5    Good
# 7                  32    Good
# ...               ...     ...
# 345086              1     Low
# 345090              1     Low
# 345097              1     Low
# 345117              4    Good
# 345177              1     Low
#
# [58276 rows x 8 columns]

# %%
new=file.iloc[:,[2,3,4]]

# %%
new
# Out:
#                                                      Body  \
# 0       I often hear about subatomic particles having ...
# 1       How would you explain string theory to non phy...
# 2       This is a question that has been posted at man...
# 5       What are the main problems that we need to sol...
# 7       Hamilton's principle states that a dynamic sys...
# ...                                                   ...
# 345086  If lagrangian is dependent only on $v^2$, then...
# 345090  Let there be a ring of mass m and radius r. Le...
# 345097  Just watched a video explaining how oil film c...
# 345117  I have been taught that the boundary condition...
# 345177  I am not happy about the derivation of Yang-Mi...
#
#                                                     Title  \
# 0       What is spin as it relates to subatomic partic...
# 1       What is your simplest explanation of the strin...
# 2        Lie theory, Representations and particle physics
# 5                      Will Determinism be ever possible?
# 7                                    Hamilton's Principle
# ...                                                   ...
# 345086                      Lagrangian for inertial frame
# 345090                       A basic question on rotation
# 345097  EM waves cancelling each other - do they inter...
# 345117  Why does the Schrödinger equation work so well...
# 345177  A specific derivation of Yang-Mills equations ...
#
#                                                      Tags
# 0       <quantum-mechanics><particle-physics><angular-...
# 1                              <string-theory><education>
# 2       <particle-physics><group-theory><representatio...
# 5       <quantum-mechanics><quantum-interpretations><h...
# 7       <lagrangian-formalism><variational-principle><...
# ...                                                   ...
# 345086  <special-relativity><classical-mechanics><refe...
# 345090  <homework-and-exercises><rotational-dynamics><...
# 345097  <quantum-mechanics><electromagnetic-radiation>...
# 345117  <quantum-mechanics><schroedinger-equation><coo...
# 345177  <classical-mechanics><differential-geometry><t...
#
# [58276 rows x 3 columns]

# %%
body=[]
title=[]
tags=[]
for i in range(new.shape[0]):
    body.append(len(new.iloc[i,0]))
    title.append(len(new.iloc[i,1]))
    tags.append(len(new.iloc[i,2]))

# %%
new['Body_length']=body
new['Title_length']=title
new['Tags_length']=tags
new
# Out:
#                                                      Body  \
# 0       I often hear about subatomic particles having ...
# 1       How would you explain string theory to non phy...
# 2       This is a question that has been posted at man...
# 5       What are the main problems that we need to sol...
# 7       Hamilton's principle states that a dynamic sys...
# ...                                                   ...
# 345086  If lagrangian is dependent only on $v^2$, then...
# 345090  Let there be a ring of mass m and radius r. Le...
# 345097  Just watched a video explaining how oil film c...
# 345117  I have been taught that the boundary condition...
# 345177  I am not happy about the derivation of Yang-Mi...
#
#                                                     Title  \
# 0       What is spin as it relates to subatomic partic...
# 1       What is your simplest explanation of the strin...
# 2        Lie theory, Representations and particle physics
# 5                      Will Determinism be ever possible?
# 7                                    Hamilton's Principle
# ...                                                   ...
# 345086                      Lagrangian for inertial frame
# 345090                       A basic question on rotation
# 345097  EM waves cancelling each other - do they inter...
# 345117  Why does the Schrödinger equation work so well...
# 345177  A specific derivation of Yang-Mills equations ...
#
#                                                      Tags  Body_length  \
# 0       <quantum-mechanics><particle-physics><angular-...          241
# 1                              <string-theory><education>          163
# 2       <particle-physics><group-theory><representatio...          777
# 5       <quantum-mechanics><quantum-interpretations><h...          128
# 7       <lagrangian-formalism><variational-principle><...          242
# ...                                                   ...          ...
# 345086  <special-relativity><classical-mechanics><refe...          117
# 345090  <homework-and-exercises><rotational-dynamics><...          351
# 345097  <quantum-mechanics><electromagnetic-radiation>...          544
# 345117  <quantum-mechanics><schroedinger-equation><coo...          732
# 345177  <classical-mechanics><differential-geometry><t...         2091
#
#         Title_length  Tags_length
# 0                 50           69
# 1                 55           26
# 2                 48           55
# 5                 34           91
# 7                 20           53
# ...              ...          ...
# 345086            29           76
# 345090            28           97
# 345097            83           60
# 345117           118           98
# 345177            55           97
#
# [58276 rows x 6 columns]

# %%
file=file.drop(["Body","Title","Tags"],axis=1)

# %%
file=pd.concat([file,new.iloc[:,4:7]],axis=1)

# %%
file=pd.concat([file,new['Body_length']],axis=1)

# %%
file
# Out:
#             Id  ViewCount  CommentCount  FavoriteCount Quality  Title_length  \
# 0            1      13803             5             27    Good            50
# 1            2       2641             4              8    Good            55
# 2            3       2412             5             13    Good            48
# 5            7       2033             5              5    Good            34
# 7            9       9277             2             32    Good            20
# ...        ...        ...           ...            ...     ...           ...
# 345086  483671         24             2              1     Low            29
# 345090  483675         22             0              1     Low            28
# 345097  483682         60             2              1     Low            83
# 345117  483702        318             6              4    Good           118
# 345177  483765         26             1              1     Low            55
#
#         Tags_length  Body_length
# 0                69          241
# 1                26          163
# 2                55          777
# 5                91          128
# 7                53          242
# ...             ...          ...
# 345086           76          117
# 345090           97          351
# 345097           60          544
# 345117           98          732
# 345177           97         2091
#
# [58276 rows x 8 columns]

# %%
file=file.replace({"Good":2,"Low":1,"Very Low":0})

# %%
file['Quality'].value_counts()
# Out:
# 1    42774
# 2    13722
# 0     1780
# Name: Quality, dtype: int64

# %%
file
# Out:
#             Id  ViewCount  CommentCount  FavoriteCount  Quality  Title_length  \
# 0            1      13803             5             27        2            50
# 1            2       2641             4              8        2            55
# 2            3       2412             5             13        2            48
# 5            7       2033             5              5        2            34
# 7            9       9277             2             32        2            20
# ...        ...        ...           ...            ...      ...           ...
# 345086  483671         24             2              1        1            29
# 345090  483675         22             0              1        1            28
# 345097  483682         60             2              1        1            83
# 345117  483702        318             6              4        2           118
# 345177  483765         26             1              1        1            55
#
#         Tags_length  Body_length
# 0                69          241
# 1                26          163
# 2                55          777
# 5                91          128
# 7                53          242
# ...             ...          ...
# 345086           76          117
# 345090           97          351
# 345097           60          544
# 345117           98          732
# 345177           97         2091
#
# [58276 rows x 8 columns]

# %%
file.columns
# Out:
# Index(['Id', 'ViewCount', 'CommentCount', 'FavoriteCount', 'Quality',
#        'Title_length', 'Tags_length', 'Body_length'],
#       dtype='object')

# %%
x=file.loc[:,['Id', 'ViewCount', 'CommentCount', 'FavoriteCount', 'Title_length', 'Tags_length', 'Body_length']]
y=file.loc[:,['Quality']]

# %%
x
# Out:
#             Id  ViewCount  CommentCount  FavoriteCount  Title_length  \
# 0            1      13803             5             27            50
# 1            2       2641             4              8            55
# 2            3       2412             5             13            48
# 5            7       2033             5              5            34
# 7            9       9277             2             32            20
# ...        ...        ...           ...            ...           ...
# 345086  483671         24             2              1            29
# 345090  483675         22             0              1            28
# 345097  483682         60             2              1            83
# 345117  483702        318             6              4           118
# 345177  483765         26             1              1            55
#
#         Tags_length  Body_length
# 0                69          241
# 1                26          163
# 2                55          777
# 5                91          128
# 7                53          242
# ...             ...          ...
# 345086           76          117
# 345090           97          351
# 345097           60          544
# 345117           98          732
# 345177           97         2091
#
# [58276 rows x 7 columns]

# %%
y
# Out:
#         Quality
# 0             2
# 1             2
# 2             2
# 5             2
# 7             2
# ...         ...
# 345086        1
# 345090        1
# 345097        1
# 345117        2
# 345177        1
#
# [58276 rows x 1 columns]

# %%
file
# Out:
#             Id  ViewCount  CommentCount  FavoriteCount  Quality  Title_length  \
# 0            1      13803             5             27        2            50
# 1            2       2641             4              8        2            55
# 2            3       2412             5             13        2            48
# 5            7       2033             5              5        2            34
# 7            9       9277             2             32        2            20
# ...        ...        ...           ...            ...      ...           ...
# 345086  483671         24             2              1        1            29
# 345090  483675         22             0              1        1            28
# 345097  483682         60             2              1        1            83
# 345117  483702        318             6              4        2           118
# 345177  483765         26             1              1        1            55
#
#         Tags_length  Body_length
# 0                69          241
# 1                26          163
# 2                55          777
# 5                91          128
# 7                53          242
# ...             ...          ...
# 345086           76          117
# 345090           97          351
# 345097           60          544
# 345117           98          732
# 345177           97         2091
#
# [58276 rows x 8 columns]

# %%
file.ViewCount.describe()
# Out:
# count     58276.000000
# mean       2272.624305
# std        9401.022208
# min           5.000000
# 25%         145.000000
# 50%         413.000000
# 75%        1329.000000
# max      785052.000000
# Name: ViewCount, dtype: float64

# %% [raw]
# For View Count Standard Deviation is more than the mean so there data is spread all over so no outliers in Viewcount

# %%
file.CommentCount.describe()
# Out:
# count    58276.000000
# mean         2.696376
# std          3.189003
# min          0.000000
# 25%          0.000000
# 50%          2.000000
# 75%          4.000000
# max         67.000000
# Name: CommentCount, dtype: float64

# %% [raw]
# For CommentCount Standard Deviation is more than the mean so there data is spread all over so no outliers in CommentCount

# %%
file.FavoriteCount.describe()
# Out:
# count    58276.000000
# mean         2.413738
# std          5.486853
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max        502.000000
# Name: FavoriteCount, dtype: float64

# %% [raw]
# For FavoriteCount Standard Deviation is more than the mean so there data is spread all over so no outliers in FavoriteCount

# %%
file.Title_length.describe()
# Out:
# count    58276.000000
# mean        57.488246
# std         24.022357
# min         15.000000
# 25%         40.000000
# 50%         54.000000
# 75%         71.000000
# max        150.000000
# Name: Title_length, dtype: float64

# %%
from scipy.stats import norm
pl.hist(file.Title_length, bins=20, rwidth=0.8, density=True)
pl.xlabel('Title_length')
pl.ylabel('Id')
rng = np.arange(file.Title_length.min(), file.Title_length.max(), 0.1)
pl.plot(rng, norm.pdf(rng,file.Title_length.mean(),file.Title_length.std()))

# %%
u=file.Title_length.mean()+(3*file.Title_length.std())
l=file.Title_length.mean()-(3*file.Title_length.std())

# %%
file[(file.Title_length>u)|(file.Title_length<l)]
# Out:
#             Id  ViewCount  CommentCount  FavoriteCount  Quality  Title_length  \
# 865        944       4060             1              5        2           147
# 1258      1368       8172             2             13        2           132
# 2128      2328       7745             8              3        2           147
# 2834      3107        550             0              3        2           133
# 3749      4156       3229             2             14        2           134
# ...        ...        ...           ...            ...      ...           ...
# 341941  480091         33            10              1        1           133
# 343341  481762         25             4              1        1           141
# 344342  482864         11             1              1        1           135
# 344538  483075         30             2              1        1           135
# 345066  483649         11             1              1        1           146
#
#         Tags_length  Body_length
# 865              47          455
# 1258             97          580
# 2128             60          570
# 2834             22          120
# 3749             79         1030
# ...             ...          ...
# 341941           66          571
# 343341           14          605
# 344342           24          136
# 344538           23          266
# 345066           42          605
#
# [639 rows x 8 columns]

# %%
file.shape
# Out:
# (58276, 8)

# %%
639/58276
# Out:
# 0.010965062804585078

# %% [raw]
# we can remove 639 outliers values as it's only around 1% of total dataset

# %%
file=file[(file.Title_length<u)&(file.Title_length>l)]

# %%
file
# Out:
#             Id  ViewCount  CommentCount  FavoriteCount  Quality  Title_length  \
# 0            1      13803             5             27        2            50
# 1            2       2641             4              8        2            55
# 2            3       2412             5             13        2            48
# 5            7       2033             5              5        2            34
# 7            9       9277             2             32        2            20
# ...        ...        ...           ...            ...      ...           ...
# 345086  483671         24             2              1        1            29
# 345090  483675         22             0              1        1            28
# 345097  483682         60             2              1        1            83
# 345117  483702        318             6              4        2           118
# 345177  483765         26             1              1        1            55
#
#         Tags_length  Body_length
# 0                69          241
# 1                26          163
# 2                55          777
# 5                91          128
# 7                53          242
# ...             ...          ...
# 345086           76          117
# 345090           97          351
# 345097           60          544
# 345117           98          732
# 345177           97         2091
#
# [57637 rows x 8 columns]

# %%
file.Tags_length.describe()
# Out:
# count    57637.000000
# mean        53.216823
# std         23.106047
# min          5.000000
# 25%         36.000000
# 50%         53.000000
# 75%         71.000000
# max        129.000000
# Name: Tags_length, dtype: float64

# %%
from scipy.stats import norm
pl.hist(file.Tags_length, bins=20, rwidth=0.8, density=True)
pl.xlabel('Tags_length')
pl.ylabel('Id')
rng = np.arange(file.Tags_length.min(), file.Tags_length.max(), 0.1)
pl.plot(rng, norm.pdf(rng,file.Tags_length.mean(),file.Tags_length.std()))

# %%
u=file.Tags_length.mean()+(3*file.Tags_length.std())
l=file.Tags_length.mean()-(3*file.Tags_length.std())

# %%
file[(file.Tags_length>u)|(file.Tags_length<l)]
# Out:
#            Id  ViewCount  CommentCount  FavoriteCount  Quality  Title_length  \
# 86838  113241       1065             1              8        2            35
#
#        Tags_length  Body_length
# 86838          129         3912

# %%
1/57637
# Out:
# 1.7349966167565972e-05

# %% [raw]
# we can remove these 1 outlier as it won't have much effect in the model as it has only less than 1% of total data

# %%
file=file[(file.Tags_length<u)&(file.Tags_length>l)]

# %%
file
# Out:
#             Id  ViewCount  CommentCount  FavoriteCount  Quality  Title_length  \
# 0            1      13803             5             27        2            50
# 1            2       2641             4              8        2            55
# 2            3       2412             5             13        2            48
# 5            7       2033             5              5        2            34
# 7            9       9277             2             32        2            20
# ...        ...        ...           ...            ...      ...           ...
# 345086  483671         24             2              1        1            29
# 345090  483675         22             0              1        1            28
# 345097  483682         60             2              1        1            83
# 345117  483702        318             6              4        2           118
# 345177  483765         26             1              1        1            55
#
#         Tags_length  Body_length
# 0                69          241
# 1                26          163
# 2                55          777
# 5                91          128
# 7                53          242
# ...             ...          ...
# 345086           76          117
# 345090           97          351
# 345097           60          544
# 345117           98          732
# 345177           97         2091
#
# [57636 rows x 8 columns]

# %%
file.Body_length.describe()
# Out:
# count    57636.000000
# mean       891.986224
# std        838.760020
# min         32.000000
# 25%        375.000000
# 50%        657.000000
# 75%       1133.000000
# max      22793.000000
# Name: Body_length, dtype: float64

# %%
pl.hist(file.Body_length, bins=20, rwidth=0.8, density=True)
pl.xlabel('Body_length')
pl.ylabel('Id')
rng = np.arange(file.Body_length.min(), file.Body_length.max(), 0.1)
pl.plot(rng, norm.pdf(rng,file.Body_length.mean(),file.Body_length.std()))

# %%
u=file.Body_length.mean()+(3*file.Body_length.std())
l=file.Body_length.mean()-(3*file.Body_length.std())

# %%
file[(file.Body_length>u)|(file.Body_length<l)]
# Out:
#             Id  ViewCount  CommentCount  FavoriteCount  Quality  Title_length  \
# 1414      1544       1075            24              8        2            32
# 1808      1975       2084             7             11        2            64
# 2518      2757       1216            15              1        1            36
# 2617      2865       4863            64             26        2            53
# 3377      3718       3137             3              4        1            81
# ...        ...        ...           ...            ...      ...           ...
# 341936  480086         35             5              1        1            85
# 343442  481880         46             2              1        1            98
# 343881  482367        143             0              1        1            41
# 344328  482848         40             3              2        1            87
# 344759  483318        112            12              1        1           106
#
#         Tags_length  Body_length
# 1414             75         4485
# 1808             36         3825
# 2518             29         4129
# 2617             60        19938
# 3377             22         4428
# ...             ...          ...
# 341936          104         8651
# 343442           95         6023
# 343881           49         7722
# 344328          100         4169
# 344759           77         4187
#
# [967 rows x 8 columns]

# %%
967/54679
# Out:
# 0.01768503447392966

# %% [raw]
# we will remove 967 outliers from the dataset as it has only about 1% of the total data

# %%
file=file[(file.Body_length<u)&(file.Body_length>l)]

# %%
file
# Out:
#             Id  ViewCount  CommentCount  FavoriteCount  Quality  Title_length  \
# 0            1      13803             5             27        2            50
# 1            2       2641             4              8        2            55
# 2            3       2412             5             13        2            48
# 5            7       2033             5              5        2            34
# 7            9       9277             2             32        2            20
# ...        ...        ...           ...            ...      ...           ...
# 345086  483671         24             2              1        1            29
# 345090  483675         22             0              1        1            28
# 345097  483682         60             2              1        1            83
# 345117  483702        318             6              4        2           118
# 345177  483765         26             1              1        1            55
#
#         Tags_length  Body_length
# 0                69          241
# 1                26          163
# 2                55          777
# 5                91          128
# 7                53          242
# ...             ...          ...
# 345086           76          117
# 345090           97          351
# 345097           60          544
# 345117           98          732
# 345177           97         2091
#
# [56669 rows x 8 columns]

# %%
file=file.drop(['Id'],axis=1)

# %%
file.isnull().value_counts()
# Out:
# ViewCount  CommentCount  FavoriteCount  Quality  Title_length  Tags_length  Body_length
# False      False         False          False    False         False        False          56669
# dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
file.columns
# Out:
# Index(['ViewCount', 'CommentCount', 'FavoriteCount', 'Quality', 'Title_length',
#        'Tags_length', 'Body_length'],
#       dtype='object')

# %%
x=file.loc[:,['ViewCount', 'CommentCount', 'FavoriteCount', 'Title_length',
       'Tags_length', 'Body_length']]
y=file.loc[:,['Quality']]

# %%
x
# Out:
#         ViewCount  CommentCount  FavoriteCount  Title_length  Tags_length  \
# 0           13803             5             27            50           69
# 1            2641             4              8            55           26
# 2            2412             5             13            48           55
# 5            2033             5              5            34           91
# 7            9277             2             32            20           53
# ...           ...           ...            ...           ...          ...
# 345086         24             2              1            29           76
# 345090         22             0              1            28           97
# 345097         60             2              1            83           60
# 345117        318             6              4           118           98
# 345177         26             1              1            55           97
#
#         Body_length
# 0               241
# 1               163
# 2               777
# 5               128
# 7               242
# ...             ...
# 345086          117
# 345090          351
# 345097          544
# 345117          732
# 345177         2091
#
# [56669 rows x 6 columns]

# %%
y
# Out:
#         Quality
# 0             2
# 1             2
# 2             2
# 5             2
# 7             2
# ...         ...
# 345086        1
# 345090        1
# 345097        1
# 345117        2
# 345177        1
#
# [56669 rows x 1 columns]

# %%
y.value_counts()
# Out:
# Quality
# 1          41647
# 2          13285
# 0           1737
# dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=1)
model1=LogisticRegression()

# %%
model1.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred1=model1.predict(x_test)
sf=StratifiedKFold(n_splits=10)

# %%
cross_val_score(model1,x_test,y_test,cv=sf,scoring='accuracy').mean()
# Out:
# 0.8073641802399971

# %%
accuracy_score(y_test,y_pred1)
# Out:
# 0.8077760131756956

# %%
from sklearn.naive_bayes import MultinomialNB
model2=MultinomialNB()
model2.fit(x_train, y_train)
cross_val_score(model2,x_test,y_test,cv=sf,scoring='accuracy').mean()
# Out:
# 0.688430680914341

# %%
accuracy_score(y_test,model2.predict(x_test))
# Out:
# 0.6616669607670137

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
f=[]
for i in range(3,15):   
    model3=RandomForestClassifier(max_depth=i,random_state=1)
    model3.fit(x_train,y_train)
    f.append(cross_val_score(model3,x_test,y_test,cv=sf,scoring='accuracy').mean())
print(max(f))
# Out:
# 0.8304804786111977

# %%
f
# Out:
# [0.8234221738077949,
#  0.8269513435003631,
#  0.8292453574022203,
#  0.8294806169381334,
#  0.8304804786111977,
#  0.8298925199709514,
#  0.8300689213957189,
#  0.8301866030362763,
#  0.8291276411799288,
#  0.8283631082062455,
#  0.8277748729121278,
#  0.8274218971539232]

# %%
model3=RandomForestClassifier(max_depth=7,random_state=1)
model3.fit(x_train,y_train)
cross_val_score(model3,x_test,y_test,cv=sf,scoring='accuracy').mean()
# Out:
# 0.8304804786111977

# %%
accuracy_score(y_test,model3.predict(x_test))
# Out:
# 0.8314216810775836

# %%
from xgboost import XGBClassifier
model4=XGBClassifier(random_state=1,max_depth=i)
model4.fit(x_train,y_train)
cross_val_score(model4,x_test,y_test,cv=sf,scoring='accuracy').mean()
# Out:
# 0.8224223812981982

# %%
accuracy_score(y_test,model4.predict(x_test))
# Out:
# 0.8264807952473384
